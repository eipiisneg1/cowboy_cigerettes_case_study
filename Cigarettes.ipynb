# %% [markdown]
# # Springboard Time Series - 'Cowboy Cigarettes' Case Study - Tier 1

# %% [markdown]
# ## Brief
#
# You're working in the US federal government as a data scientist in the Health and Environment department. You've been tasked with determining whether sales for the oldest and most powerful producers of cigarettes in the country are increasing or declining.
#
# **Cowboy Cigarettes (TM, *est.* 1890)** is the US's longest-running cigarette manufacturer. Like many cigarette companies, however, they haven't always been that public about their sales and marketing data. The available post-war historical data runs for only 11 years after they resumed production in 1949; stopping in 1960 before resuming again in 1970. Your job is to use the 1949-1960 data to predict whether the manufacturer's cigarette sales actually increased, decreased, or stayed the same. You need to make a probable reconstruction of the sales record of the manufacturer - predicting the future, from the perspective of the past - to contribute to a full report on US public health in relation to major cigarette companies.
#
# The results of your analysis will be used as part of a major report relating public health and local economics, and will be combined with other studies executed by your colleagues to provide important government advice.
#
# -------------------------------
# As ever, this notebook is **tiered**, meaning you can elect that tier that is right for your confidence and skill level. There are 3 tiers, with tier 1 being the easiest and tier 3 being the hardest.
#
# **1. Sourcing and loading**
# - Load relevant libraries
# - Load the data
# - Explore the data
#
#
# **2. Cleaning, transforming and visualizing**
# - Dropping unwanted columns
# - Nomenclature
# - Type conversions
# - Making a predictor variable `y`
# - Getting summary statistics for `y`
# - Plotting `y`
#
#
# **3. Modelling**
# - Decomposition
#     - Trend
#     - Seasonality
#     - Noise
# - Testing for stationarity with KPSS
# - Making the data stationary
# - The ARIMA Model
#     - Make a function to find the MSE of a single ARIMA model
#     - Make a function to evaluate the different ARIMA models with different p, d, and q values
# - Visualize the results
# - Application: Forecasting
#
# **4. Evaluating and concluding**
# - What is our conclusion?
# - Next steps

# %% [markdown]
# ## 0. Preliminaries
#
# Time series data is just any data displaying how a single variable changes over time. It comes as a collection of metrics typically taken at regular intervals. Common examples of time series data include weekly sales data and daily stock prices. You can also easily acquire time series data from [Google Trends](https://trends.google.com/trends/?geo=US), which shows you how popular certain search terms are, measured in number of Google searches.

# %% [markdown]
# ## 1. Sourcing and Loading
#
# ### 1a. Load relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import statsmodels.api as sm
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1b. Load the data
# Call the variable `cigData`.

# %%
cigData = pd.read_csv('CowboyCigsData.csv')
cigData_decompose = pd.read_csv('CowboyCigsData.csv')

# %%
cigData.info(); print(); cigData.describe(); print(); cigData.head(13)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  144 non-null    int64
#  1   Time        144 non-null    object
#  2   #CigSales   144 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 3.5+ KB
#     Unnamed: 0     Time  #CigSales
# 0            0  1949-01    1000112
# 1            1  1949-02    1000118
# 2            2  1949-03    1000132
# 3            3  1949-04    1000129
# 4            4  1949-05    1000121
# 5            5  1949-06    1000135
# 6            6  1949-07    1000148
# 7            7  1949-08    1000148
# 8            8  1949-09    1000136
# 9            9  1949-10    1000119
# 10          10  1949-11    1000104
# 11          11  1949-12    1000118
# 12          12  1950-01    1000115

# %%
cigData.drop(['Unnamed: 0'], inplace=True, axis=1)
cigData_decompose.drop(['Unnamed: 0'], inplace=True, axis=1)

# %% [markdown]
# ### 1c. Explore the data
# We now need to check whether the data conduces to a time series style analysis.
#
# It doesn't conduce.

# %%
cigData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       144 non-null    object
#  1   #CigSales  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# Over a million cigarettes sold in the month of January 1949. This certainly is a popular cigarette brand.

# %%
cigData.rename({'#CigSales':'Sales'}, axis=1, inplace=True)
cigData_decompose.rename({'#CigSales':'Sales'}, axis=1, inplace=True)

cigData.rename({'Time':'Months'}, axis=1, inplace=True)
cigData_decompose.rename({'Time':'Months'}, axis=1, inplace=True)

# %%
cigData_decompose.head()
# Out:
#     Months    Sales
# 0  1949-01  1000112
# 1  1949-02  1000118
# 2  1949-03  1000132
# 3  1949-04  1000129
# 4  1949-05  1000121

# %%
cigData.head()
# Out:
#     Months    Sales
# 0  1949-01  1000112
# 1  1949-02  1000118
# 2  1949-03  1000132
# 3  1949-04  1000129
# 4  1949-05  1000121

# %%
cigData['Months'] = pd.to_datetime(cigData['Months'])

# %%
cigData['Sales'].sum()
# Out:
# 144040363

# %%
cigData.isnull().values.any()
# Out:
# False

# %%
sns.relplot(x='Months', y="Sales", data=cigData, kind="line")

# %%
cigData.set_index('Months', inplace=True)

# %% [markdown]
# ### 2d. Making a predictor variable `y`

# %% [markdown]
# The data is now indexed by date, as time series data ought to be.
#
# Since we want to predict the number of cigarette sales at Cowboy cigarettes, and `y` is typically used to signify a predictor variable, let's create a new variable called `y` and assign the indexed #Passenger column.

# %%
cigData.head()
# Out:
#               Sales
# Months
# 1949-01-01  1000112
# 1949-02-01  1000118
# 1949-03-01  1000132
# 1949-04-01  1000129
# 1949-05-01  1000121

# %%
y = cigData['Sales']

# %% [markdown]
# Check the type of our new variable.

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 2e. Getting summary statistics for `y`

# %% [markdown]
# Get the summary statistics of our data here.

# %%
cigData.describe()
# Out:
#               Sales
# count  1.440000e+02
# mean   1.000280e+06
# std    1.199663e+02
# min    1.000104e+06
# 25%    1.000180e+06
# 50%    1.000266e+06
# 75%    1.000360e+06
# max    1.000622e+06

# %% [markdown]
# ## 3. Modelling
# ### 3a. Decomposition
# What do you notice from the plot? Take at least `2` minutes to examine the plot, and write down everything you observe.
#
# All done?
#
# We can see that, generally, there is a trend upwards in cigarette sales from at Cowboy Cigarettes. But there are also some striking - and perhaps unexpected - seasonal fluctuations. These seasonal fluctations come in a repeated pattern. Work out when these seasonal fluctuations are happening, and take 2 minutes to hypothesize on their cause here.
#
# What does it mean to *decompose* time series data? It means breaking that data into 3 components:
#
# 1. **Trend**: The overall direction that the data is travelling in (like upwards or downwards)
# 2. **Seasonality**: Cyclical patterns in the data
# 3. **Noise**: The random variation in the data
#
# We can treat these components differently, depending on the question and what's appropriate in the context. They can either be added together in an *additive* model, or multiplied together in a *multiplicative* model.
#
# Make a coffee, take `5` minutes and read [this article](https://medium.com/@sigmundojr/seasonality-in-python-additive-or-multiplicative-model-d4b9cf1f48a7) and think about whether our data would conduce to an additive or multiplicative model here. Write your conclusion down just here:
#
# -------------------------------

# %% [markdown]
# All done? Well, just on the basis of the plot above, it seems our Cowboy Cigarettes data is actually multiplicative.
#
# That's because, as time progresses, the general trend seems to be increasing *at a rate that's also increasing*. We also see that the seasonal fluctuations (the peaks and troughs) get bigger and bigger as time progresses.
#
# Now on the other hand, if the data were simply additive, we could expect the general trend to increase at a *steadily*, and a constant speed; and also for seasonal ups and downs not to increase or decrease in extent over time.
#
# Happily, we can use the `decompose()` function to quantify the component parts described above in our data.

# %%
# Import seasonal_decompose 
from statsmodels.tsa.seasonal import seasonal_decompose

# Make a variable called decomposition, and assign it y passed to seasonal_decompose() 
decomposition = seasonal_decompose(y)

# Make three variables for trend, seasonal and residual components respectively. 
# Assign them the relevant features of decomposition 
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot the original data, the trend, the seasonality, and the residuals 
plt.subplot(411)
plt.plot(y, label = 'y')
plt.legend(loc = 'best')

plt.subplot(412)
plt.plot(trend, label = 'Trend')
plt.legend(loc = 'best')

plt.subplot(413)
plt.plot(seasonal, label = 'seasonal')
plt.legend(loc = 'best')

plt.subplot(414)
plt.plot(residual, label = 'Residuals')
plt.legend(loc = 'best')

plt.tight_layout()

# %% [markdown]
# ### 3b. Testing for stationarity with KPSS
# As you know, when doing time series analysis we always have to check for stationarity. Imprecisely, a time series dataset is stationary just if its statistical features don't change over time. A little more precisely, a stationary time series dataset will have constant mean, variance, and covariance.
#
# There are many ways to test for stationarity, but one of the most common is the KPSS test. The Null hypothesis of this test is that the time series data in question is stationary; hence, if the *p*-value is less than the significance level (typically 0.05, but we decide) then we reject the Null and infer that the data is not stationary.

# %%
from statsmodels.tsa.stattools import kpss
kpss(y)
# Out:
# /Users/jshensley/.conda/envs/DataScienceGuidedCapstone/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# (1.651312235417082,
#  0.01,
#  8,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# Since our p-value is less than 0.05, we should reject the Null hypothesis and deduce the non-stationarity of our data.
#
# But our data need to be stationary! So we need to do some transforming.

# %% [markdown]
# ### 3c. Making the data stationary
# Let's recall what it looks like.

# %%
y.head()
# Out:
# Months
# 1949-01-01    1000112
# 1949-02-01    1000118
# 1949-03-01    1000132
# 1949-04-01    1000129
# 1949-05-01    1000121
# Name: Sales, dtype: int64

# %% [markdown]
# In our plot, we can see that both the mean and the variance *increase as time progresses*. At the moment, our data has neither a constant mean, nor a constant variance (the covariance, however, seems constant).
#
# One oft used way of getting rid of changing variance is to take the natural log of all the values in our dataset. Let's do this now.

# %%
# Declare a variable called y_log
y_log = np.log(y)

# %% [markdown]
# When you plot this, you can see how the variance in our data now remains constant over time.

# %%
y_log.head()
# Out:
# Months
# 1949-01-01    13.815623
# 1949-02-01    13.815629
# 1949-03-01    13.815643
# 1949-04-01    13.815640
# 1949-05-01    13.815632
# Name: Sales, dtype: float64

# %%
cigData['Sales'].plot()
# Out:
# <AxesSubplot:xlabel='Months'>

# %%
y_log.plot()
# Out:
# <AxesSubplot:xlabel='Months'>

# %% [markdown]
# We now have a constant variance, but we also need a constant mean.
#
# We can do this by *differencing* our data. We difference a time series dataset when we create a new time series comprising the difference between the values of our existing dataset.
#
# Python is powerful, and we can use the `diff()` function to do this. You'll notice there's one less value than our existing dataset (since we're taking the difference between the existing values).

# %%
kpss(y_log.diff().dropna())
# Out:
# /Users/jshensley/.conda/envs/DataScienceGuidedCapstone/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# (0.023897674207570566,
#  0.1,
#  7,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# Our p-value is now greater than 0.05, so we can accept the null hypothesis that our data is stationary.

# %% [markdown]
# ### 3d. The ARIMA model
#
# Recall that ARIMA models are based around the idea that it's possible to predict the next value in a time series by using information about the most recent data points. It also assumes there will be some randomness in our data that can't ever be predicted.
#
# We can find some good parameters for our model using the `sklearn` and `statsmodels` libraries, and in particular `mean_squared_error` and `ARIMA`.

# %%
# Import mean_squared_error and ARIMA
from sklearn.metrics import mean_squared_error
# from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
# from statsmodels import tsa.SARIMAX

# %% [markdown]
# #### 3di. Make a function to find the MSE of a single ARIMA model

# %%
# Make a function called evaluate_arima_model to find the MSE of a single ARIMA model 
# noinspection PyUnusedLocal
def evaluate_arima_model(data,arima_order):
    # Needs to be an integer because it is later used as an index.
    # Use int()

    split = int(len(data) * 0.8)

    train,test = data[:split], data[split:]
    past = list(train)

    # make predictions
    predictions = []
    for i in range(len(test)):  #timestep-wise comparison between test data and one-step prediction ARIMA model.
    	print(f'i is {i} and i am inside for loop for ARIMA model')
    	model = ARIMA(past,order=arima_order)
    	model_fit = model.fit()

    	future = model_fit.forecast()[0]
    	print(f'future is {future}')

    	predictions.append(future)
    	past.append(test[i])

    print(f'in predictions list {predictions}')
    # calculate out of sample error

    error = mean_squared_error(test,predictions)
    # Return the error
    print(f'error is {error}')
    return error

# %% [markdown]
# #### 3dii. Make a function to evaluate the different ARIMA models with different p, d, and q values

# %%
# Make a function called evaluate_models to evaluate different ARIMA models with several different p, d, and q values.
# noinspection TryExceptContinue,PyBroadException
def evaluate_models(dataset,p_values,d_values,q_values):

    best_score, best_cfg = float("inf"), None
    print(f'best_score = {best_score}, best_cfg = {best_cfg}')

    	# Iterate through p_values

    for p in p_values:
        		# Iterate through d_values
        for d in d_values:
            			# Iterate through q_values
            for q in q_values:
                # p, d, q iterator variables in that order
                order = (p,d,q)
                print(order)
                try:
                    # Make a variable called mse for the Mean squared error
                    mse = evaluate_arima_model(dataset,order)
                    if mse < best_score:
                    	print(f'mse {mse} is less than best_score {best_score}')
                    	best_score, best_cfg = mse, order
                    print(f'ARIMA {order} and MSE {mse}')

                except Exception:
                    continue
    print('Best ARIMA%s MSE=%.3f' % (best_cfg,best_score))

# %%
# Now, we choose a couple of values to try for each parameter: p_values, d_values and q_values
# Fill in the blanks as appropriate
p_values = [p for p in range(0, 3)]
d_values = [d for d in range(0, 3)]
q_values = [q for q in range(0, 3)]
print(p_values, d_values, q_values, sep='\n\n')
# Out:
# [0, 1, 2]
#
# [0, 1, 2]
#
# [0, 1, 2]

# %%
# Finally, we can find the optimum ARIMA model for our data.
# Nb. this can take a while...!
import warnings
warnings.filterwarnings("ignore")
evaluate_models(y_log, p_values, d_values, q_values)
# Out:
# best_score = inf, best_cfg = None
# (0, 0, 0)
# i is 0 and i am inside for loop for ARIMA model
# future is 13.815745694715426
# i is 1 and i am inside for loop for ARIMA model
# future is 13.815748002460467
# i is 2 and i am inside for loop for ARIMA model
# future is 13.815749430378286
# i is 3 and i am inside for loop for ARIMA model
# future is 13.815750519357529
# i is 4 and i am inside for loop for ARIMA model
# future is 13.81575106075469
# i is 5 and i am inside for loop for ARIMA model
# future is 13.815751631497033
# i is 6 and i am inside for loop for ARIMA model
# future is 13.815752561484558
# i is 7 and i am inside for loop for ARIMA model
# future is 13.815753345873066
# i is 8 and i am inside for loop for ARIMA model
# future is 13.815754823144056
# i is 9 and i am inside for loop for ARIMA model
# future is 13.81575523290108
# i is 10 and i am inside for loop for ARIMA model
# future is 13.815757254752343
# i is 11 and i am inside for loop for ARIMA model
# future is 13.815758939662722
# i is 12 and i am inside for loop for ARIMA model
# future is 13.8157610920301
# i is 13 and i am inside for loop for ARIMA model
# future is 13.8157636962281
# i is 14 and i am inside for loop for ARIMA model
# future is 13.815765239041525
# i is 15 and i am inside for loop for ARIMA model
# future is 13.815763845226916
# i is 16 and i am inside for loop for ARIMA model
# future is 13.81576723163959
# i is 17 and i am inside for loop for ARIMA model
# future is 13.815768009809842
# i is 18 and i am inside for loop for ARIMA model
# future is 13.815769007337433
# i is 19 and i am inside for loop for ARIMA model
# future is 13.815770320201752
# i is 20 and i am inside for loop for ARIMA model
# future is 13.815771348370392
# i is 21 and i am inside for loop for ARIMA model
# future is 13.815772527894007
# i is 22 and i am inside for loop for ARIMA model
# future is 13.815773834476817
# i is 23 and i am inside for loop for ARIMA model
# future is 13.815775771083764
# i is 24 and i am inside for loop for ARIMA model
# future is 13.815778706429064
# i is 25 and i am inside for loop for ARIMA model
# future is 13.815781043326412
# i is 26 and i am inside for loop for ARIMA model
# future is 13.815782648778825
# i is 27 and i am inside for loop for ARIMA model
# future is 13.815783949605374
# i is 28 and i am inside for loop for ARIMA model
# future is 13.815784738284327
# in predictions list [13.815745694715426, 13.815748002460467, 13.815749430378286, 13.815750519357529, 13.81575106075469, 13.815751631497033, 13.815752561484558, 13.815753345873066, 13.815754823144056, 13.81575523290108, 13.815757254752343, 13.815758939662722, 13.8157610920301, 13.8157636962281, 13.815765239041525, 13.815763845226916, 13.81576723163959, 13.815768009809842, 13.815769007337433, 13.815770320201752, 13.815771348370392, 13.815772527894007, 13.815773834476817, 13.815775771083764, 13.815778706429064, 13.815781043326412, 13.815782648778825, 13.815783949605374, 13.815784738284327]
# error is 4.0266372219779305e-08
# mse 4.0266372219779305e-08 is less than best_score inf
# ARIMA (0, 0, 0) and MSE 4.0266372219779305e-08
# (0, 0, 1)
# i is 0 and i am inside for loop for ARIMA model
# future is 13.815745630825885
# i is 1 and i am inside for loop for ARIMA model
# future is 13.815747303282237
# i is 2 and i am inside for loop for ARIMA model
# future is 13.815749289770588
# i is 3 and i am inside for loop for ARIMA model
# future is 13.815749111790657
# i is 4 and i am inside for loop for ARIMA model
# future is 13.81574960375687
# i is 5 and i am inside for loop for ARIMA model
# future is 13.815750775639609
# i is 6 and i am inside for loop for ARIMA model
# future is 13.81575139586408
# i is 7 and i am inside for loop for ARIMA model
# future is 13.81575206308813
# i is 8 and i am inside for loop for ARIMA model
# future is 13.815754518032618
# i is 9 and i am inside for loop for ARIMA model
# future is 13.8157545730879
# i is 10 and i am inside for loop for ARIMA model
# future is 13.815757074794393
# i is 11 and i am inside for loop for ARIMA model
# future is 13.815759119923078
# i is 12 and i am inside for loop for ARIMA model
# future is 13.815761567236486
# i is 13 and i am inside for loop for ARIMA model
# future is 13.81576341798339
# i is 14 and i am inside for loop for ARIMA model
# future is 13.815766223686209
# i is 15 and i am inside for loop for ARIMA model
# future is 13.815765848194074
# i is 16 and i am inside for loop for ARIMA model
# future is 13.815766597666274
# i is 17 and i am inside for loop for ARIMA model
# future is 13.81576838336373
# i is 18 and i am inside for loop for ARIMA model
# future is 13.815769184017281
# i is 19 and i am inside for loop for ARIMA model
# future is 13.815769848387323
# i is 20 and i am inside for loop for ARIMA model
# future is 13.815771692479062
# i is 21 and i am inside for loop for ARIMA model
# future is 13.81577316330789
# i is 22 and i am inside for loop for ARIMA model
# future is 13.815774488801717
# i is 23 and i am inside for loop for ARIMA model
# future is 13.81577662321748
# i is 24 and i am inside for loop for ARIMA model
# future is 13.815778938955434
# i is 25 and i am inside for loop for ARIMA model
# future is 13.815781171937159
# i is 26 and i am inside for loop for ARIMA model
# future is 13.815782380202583
# i is 27 and i am inside for loop for ARIMA model
# future is 13.81578460842784
# i is 28 and i am inside for loop for ARIMA model
# future is 13.81578513322472
# in predictions list [13.815745630825885, 13.815747303282237, 13.815749289770588, 13.815749111790657, 13.81574960375687, 13.815750775639609, 13.81575139586408, 13.81575206308813, 13.815754518032618, 13.8157545730879, 13.815757074794393, 13.815759119923078, 13.815761567236486, 13.81576341798339, 13.815766223686209, 13.815765848194074, 13.815766597666274, 13.81576838336373, 13.815769184017281, 13.815769848387323, 13.815771692479062, 13.81577316330789, 13.815774488801717, 13.81577662321748, 13.815778938955434, 13.815781171937159, 13.815782380202583, 13.81578460842784, 13.81578513322472]
# error is 4.024729608919216e-08
# mse 4.024729608919216e-08 is less than best_score 4.0266372219779305e-08
# ARIMA (0, 0, 1) and MSE 4.024729608919216e-08
# (0, 0, 2)
# i is 0 and i am inside for loop for ARIMA model
# future is 13
# i is 13 and i am inside for loop for ARIMA model
# future is 13.816068092694106
# i is 14 and i am inside for loop for ARIMA model
# future is 13.815944903786873
# i is 15 and i am inside for loop for ARIMA model
# future is 13.815906905559725
# i is 16 and i am inside for loop for ARIMA model
# future is 13.81586196657738
# i is 17 and i am inside for loop for ARIMA model
# future is 13.815928058160512
# i is 18 and i am inside for loop for ARIMA model
# future is 13.815928902438571
# i is 19 and i am inside for loop for ARIMA model
# future is 13.81589318726746
# i is 20 and i am inside for loop for ARIMA model
# future is 13.81593993626721
# i is 21 and i am inside for loop for ARIMA model
# future is 13.815980714045876
# i is 22 and i am inside for loop for ARIMA model
# future is 13.815983326209988
# i is 23 and i am inside for loop for ARIMA model
# future is 13.816062023870154
# i is 24 and i am inside for loop for ARIMA model
# future is 13.816154091741462
# i is 25 and i am inside for loop for ARIMA model
# future is 13.816106630817528
# i is 26 and i am inside for loop for ARIMA model
# future is 13.815991005885516
# i is 27 and i am inside for loop for ARIMA model
# future is 13.81596394775678
# i is 28 and i am inside for loop for ARIMA model
# future is 13.815877894053793
# in predictions list [13.816011201924576, 13.816015715666563, 13.815888172807144, 13.815864995409179, 13.815807557943328, 13.815857179212593, 13.81587484062193, 13.815846762827228, 13.815934958559623, 13.815900690990896, 13.81593715607229, 13.815993835111458, 13.816077642115049, 13.816068092694106, 13.815944903786873, 13.815906905559725, 13.81586196657738, 13.815928058160512, 13.815928902438571, 13.81589318726746, 13.81593993626721, 13.815980714045876, 13.815983326209988, 13.816062023870154, 13.816154091741462, 13.816106630817528, 13.815991005885516, 13.81596394775678, 13.815877894053793]
# error is 2.452412341883781e-09
# ARIMA (1, 1, 1) and MSE 2.452412341883781e-09
# (1, 1, 2)
# i is 0 and i am inside for loop for ARIMA model
# future is 13.816001495364365
# i is 1 and i am inside for loop for ARIMA model
# future is 13.816009320411844
# i is 2 and i am inside for loop for ARIMA model
# future is 13.81588075065001
# i is 3 and i am inside for loop for ARIMA model
# future is 13.815875746974875
# i is 4 and i am inside for loop for ARIMA model
# future is 13.815813188667798
# i is 5 and i am inside for loop for ARIMA model
# future is 13.815865464242666
# i is 6 and i am inside for loop for ARIMA model
# future is 13.81587444062162
# i is 7 and i am inside for loop for ARIMA model
# future is 13.815848666103822
# i is 8 and i am inside for loop for ARIMA model
# future is 13.815936292250795
# i is 9 and i am inside for loop for ARIMA model
# future is 13.815892424574486
# i is 10 and i am inside for loop for ARIMA model
# future is 13.815936825459005
# i is 11 and i am inside for loop for ARIMA model
# future is 13.815986682609054
# i is 12 and i am inside for loop for ARIMA model
# future is 13.81606955812535
# i is 13 and i am inside for loop for ARIMA model
# future is 13.816059102381004
# i is 14 and i am inside for loop for ARIMA model
# future is 13.815939127200961
# i is 15 and i am inside for loop for ARIMA model
# future is 13.815914438197373
# i is 16 and i am inside for loop for ARIMA model
# future is 13.815865397062078
# i is 17 and i am inside for loop for ARIMA model
# future is 13.815938039592867
# i is 18 and i am inside for loop for ARIMA model
# future is 13.815924728036615
# i is 19 and i am inside for loop for ARIMA model
# future is 13.815896862531899
# i is 20 and i am inside for loop for ARIMA model
# future is 13.815942562877183
# i is 21 and i am inside for loop for ARIMA model
# future is 13.81597717993201
# i is 22 and i am inside for loop for ARIMA model
# future is 13.815977972838544
# i is 23 and i am inside for loop for ARIMA model
# future is 13.816056958617425
# i is 24 and i am inside for loop for ARIMA model
# future is 13.816142798208695
# i is 25 and i am inside for loop for ARIMA model
# future is 13.816093639388647
# i is 26 and i am inside for loop for ARIMA model
# future is 13.815984804886295
# i is 27 and i am inside for loop for ARIMA model
# future is 13.815966385503216
# i is 28 and i am inside for loop for ARIMA model
# future is 13.81588226264343
# in predictions list [13.816001495364365, 13.816009320411844, 13.81588075065001, 13.815875746974875, 13.815813188667798, 13.815865464242666, 13.81587444062162, 13.815848666103822, 13.815936292250795, 13.815892424574486, 13.815936825459005, 13.815986682609054, 13.81606955812535, 13.816059102381004, 13.815939127200961, 13.815914438197373, 13.815865397062078, 13.815938039592867, 13.815924728036615, 13.815896862531899, 13.815942562877183, 13.81597717993201, 13.815977972838544, 13.816056958617425, 13.816142798208695, 13.816093639388647, 13.815984804886295, 13.815966385503216, 13.81588226264343]
# error is 2.330926249695945e-09
# mse 2.330926249695945e-09 is less than best_score 2.426903523246761e-09
# ARIMA (1, 1, 2) and MSE 2.330926249695945e-09
# (1, 2, 0)
# i is 0 and i am inside for loop for ARIMA model
# future is 13.816063499646257
# i is 1 and i am inside for loop for ARIMA model
# future is 13.816036392511563
# i is 2 and i am inside for loop for ARIMA model
# future is 13.81583111310488
# i is 3 and i am inside for loop for ARIMA model
# future is 13.815813563650126
# i is 4 and i am inside for loop for ARIMA model
# future is 13.815772642171233
# i is 5 and i am inside for loop for ARIMA model
# future is 13.81586034299657
# i is 6 and i am inside for loop for ARIMA model
# future is 13.815894641094607
# i is 7 and i am inside for loop for ARIMA model
# future is 13.815841756157733
# i is 8 and i am inside for loop for ARIMA model
# future is 13.815961087044114
# i is 9 and i am inside for loop for ARIMA model
# future is 13.815914522659371
# i is 10 and i am inside for loop for ARIMA model
# future is 13.815945725382143
# i is 11 and i am inside for loop for ARIMA model
# future is 13.816028058948023
# i is 12 and i am inside for loop for ARIMA model
# future is 13.816129038409844
# i is 13 and i am inside for loop for ARIMA model
# future is 13.81609623894025
# i is 14 and i am inside for loop for ARIMA model
# future is 13.815905689235246
# i is 15 and i am inside for loop for ARIMA model
# future is 13.815852635043866
# i is 16 and i am inside for loop for ARIMA model
# future is 13.815825236639927
# i is 17 and i am inside for loop for ARIMA model
# future is 13.81593955975582
# i is 18 and i am inside for loop for ARIMA model
# future is 13.815946275398666
# i is 19 and i am inside for loop for ARIMA model
# future is 13.815883557394724
# i is 20 and i am inside for loop for ARIMA model
# future is 13.815945400514396
# i is 21 and i am inside for loop for ARIMA model
# future is 13.81601042431628
# i is 22 and i am inside for loop for ARIMA model
# future is 13.816000141106867
# i is 23 and i am inside for loop for ARIMA model
# future is 13.
# i is 9 and i am inside for loop for ARIMA model
# future is 13.815897390147486
# i is 10 and i am inside for loop for ARIMA model
# future is 13.815956820584868
# i is 11 and i am inside for loop for ARIMA model
# future is 13.81602357432079
# i is 12 and i am inside for loop for ARIMA model
# future is 13.816121547590463
# i is 13 and i am inside for loop for ARIMA model
# future is 13.816087529742715
# i is 14 and i am inside for loop for ARIMA model
# future is 13.815912497780102
# i is 15 and i am inside for loop for ARIMA model
# future is 13.815884712152119
# i is 16 and i am inside for loop for ARIMA model
# future is 13.815828715987076
# i is 17 and i am inside for loop for ARIMA model
# future is 13.815946334881238
# i is 18 and i am inside for loop for ARIMA model
# future is 13.815929960640553
# i is 19 and i am inside for loop for ARIMA model
# future is 13.815878524993467
# i is 20 and i am inside for loop for ARIMA model
# future is 13.815953238015508
# i is 21 and i am inside for loop for ARIMA model
# future is 13.816001627966928
# i is 22 and i am inside for loop for ARIMA model
# future is 13.815991333540532
# i is 23 and i am inside for loop for ARIMA model
# future is 13.816100814713137
# i is 24 and i am inside for loop for ARIMA model
# future is 13.816202838800512
# i is 25 and i am inside for loop for ARIMA model
# future is 13.816111328916788
# i is 26 and i am inside for loop for ARIMA model
# future is 13.815961558457378
# i is 27 and i am inside for loop for ARIMA model
# future is 13.815952932359687
# i is 28 and i am inside for loop for ARIMA model
# future is 13.815831926997541
# in predictions list [13.816040671188379, 13.816042301157204, 13.815844987495696, 13.815854847563491, 13.815762879352267, 13.81586175737864, 13.815878234710787, 13.815835869750583, 13.815976134381451, 13.815897390147486, 13.815956820584868, 13.81602357432079, 13.816121547590463, 13.816087529742715, 13.815912497780102, 13.815884712152119, 13.815828715987076, 13.815946334881238, 13.815929960640553, 13.815878524993467, 13.815953238015508, 13.816001627966928, 13.815991333540532, 13.816100814713137, 13.816202838800512, 13.816111328916788, 13.815961558457378, 13.815952932359687, 13.815831926997541]
# error is 3.5848110384834647e-09
# ARIMA (2, 2, 1) and MSE 3.5848110384834647e-09
# (2, 2, 2)
# i is 0 and i am inside for loop for ARIMA model
# future is 13.816042941340934
# i is 1 and i am inside for loop for ARIMA model
# future is 13.816027381762272
# i is 2 and i am inside for loop for ARIMA model
# future is 13.815836453727076
# i is 3 and i am inside for loop for ARIMA model
# future is 13.815867849515943
# i is 4 and i am inside for loop for ARIMA model
# future is 13.815770099277364
# i is 5 and i am inside for loop for ARIMA model
# future is 13.815870813757163
# i is 6 and i am inside for loop for ARIMA model
# future is 13.815910543019408
# i is 7 and i am inside for loop for ARIMA model
# future is 13.815836674656
# i is 8 and i am inside for loop for ARIMA model
# future is 13.81596398562776
# i is 9 and i am inside for loop for ARIMA model
# future is 13.815899078645138
# i is 10 and i am inside for loop for ARIMA model
# future is 13.81595568777302
# i is 11 and i am inside for loop for ARIMA model
# future is 13.816018508392954
# i is 12 and i am inside for loop for ARIMA model
# future is 13.816123599588254
# i is 13 and i am inside for loop for ARIMA model
# future is 13.816082543195606
# i is 14 and i am inside for loop for ARIMA model
# future is 13.815913306606637
# i is 15 and i am inside for loop for ARIMA model
# future is 13.81587988253346
# i is 16 and i am inside for loop for ARIMA model
# future is 13.815833525689905
# i is 17 and i am inside for loop for ARIMA model
# future is 13.815938228110207
# i is 18 and i am inside for loop for ARIMA model
# future is 13.815928216439843
# i is 19 and i am inside for loop for ARIMA model
# future is 13.815885415077034
# i is 20 and i am inside for loop for ARIMA model
# future is 13.815947420346353
# i is 21 and i am inside for loop for ARIMA model
# future is 13.816001572944426
# i is 22 and i am inside for loop for ARIMA model
# future is 13.815992003288125
# i is 23 and i am inside for loop for ARIMA model
# future is 13.8160993185768
# i is 24 and i am inside for loop for ARIMA model
# future is 13.816198311613308
# i is 25 and i am inside for loop for ARIMA model
# future is 13.816110546397265
# i is 26 and i am inside for loop for ARIMA model
# future is 13.81590364431981
# i is 27 and i am inside for loop for ARIMA model
# future is 13.815888413334875
# i is 28 and i am inside for loop for ARIMA model
# future is 13.815837413990604
# in predictions list [13.816042941340934, 13.816027381762272, 13.815836453727076, 13.815867849515943, 13.815770099277364, 13.815870813757163, 13.815910543019408, 13.815836674656, 13.81596398562776, 13.815899078645138, 13.81595568777302, 13.816018508392954, 13.816123599588254, 13.816082543195606, 13.815913306606637, 13.81587988253346, 13.815833525689905, 13.815938228110207, 13.815928216439843, 13.815885415077034, 13.815947420346353, 13.816001572944426, 13.815992003288125, 13.8160993185768, 13.816198311613308, 13.816110546397265, 13.81590364431981, 13.815888413334875, 13.815837413990604]
# error is 3.4286286864872275e-09
# ARIMA (2, 2, 2) and MSE 3.4286286864872275e-09
# Best ARIMA(2, 1, 1) MSE=0.000

# %% [markdown]
# So the best p,d, q, parameters for our ARIMA model are 2, 1, 1 respectively. Now we know this, we can build the model.

# %%
p=2
d=1
q=1
model = ARIMA(y_log, order=(p,d,q))
model_fit = model.fit()
forecast = model_fit.forecast(24)
forecast
# Out:
# 1961-01-01    13.815979
# 1961-02-01    13.816000
# 1961-03-01    13.816006
# 1961-04-01    13.816003
# 1961-05-01    13.815998
# 1961-06-01    13.815993
# 1961-07-01    13.815991
# 1961-08-01    13.815990
# 1961-09-01    13.815991
# 1961-10-01    13.815991
# 1961-11-01    13.815992
# 1961-12-01    13.815992
# 1962-01-01    13.815992
# 1962-02-01    13.815992
# 1962-03-01    13.815992
# 1962-04-01    13.815992
# 1962-05-01    13.815992
# 1962-06-01    13.815992
# 1962-07-01    13.815992
# 1962-08-01    13.815992
# 1962-09-01    13.815992
# 1962-10-01    13.815992
# 1962-11-01    13.815992
# 1962-12-01    13.815992
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Sales   No. Observations:                  144
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                1287.245
# Date:                Tue, 25 Oct 2022   AIC                          -2566.490
# Time:                        12:54:20   BIC                          -2554.639
# Sample:                    01-01-1949   HQIC                         -2561.674
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0575   1.33e-19   7.98e+18      0.000       1.057       1.057
# ar.L2         -0.4391   7.17e-19  -6.12e+17      0.000      -0.439      -0.439
# ma.L1         -0.7080   3.89e-20  -1.82e+19      0.000      -0.708      -0.708
# sigma2      7.158e-10   2.65e-10      2.705      0.007    1.97e-10    1.23e-09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.72   Jarque-Bera (JB):                 0.63
# Prob(Q):                              0.40   Prob(JB):                         0.73
# Heteroskedasticity (H):               7.95   Skew:                             0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.

# %% [markdown]
# We can take a look at a summary of the model this library has built around our data.

# %% [markdown]
# ### 3e. Visualize the results
#
# Visualize the original dataset plotted against our model.

# %%
plt.figure(figsize=(20,9))
plt.plot(y_log.diff())
plt.show()

# %%
# Call figure() and plot() on the plt
plt.figure(figsize=(20,9))
# plt.plot(y_log.diff())
plt.plot(forecast, color = 'red')
plt.show()

# %% [markdown]
# ### 3f. Application: Forecasting
#
# We've done well: our model fits pretty closely to our existing data. Let's now use it to forecast what's likely to occur in future.

# %%
# Declare a variable called forecast_period with the amount of months to forecast, and
# create a range of future dates that is the length of the periods you've chosen to forecast
forecast_period = 96
date_range = pd.date_range(y_log.index[-1], periods = forecast_period, 
              freq='MS').strftime("%Y-%m-%d").tolist()
print(date_range)
# Out:
# ['1960-12-01', '1961-01-01', '1961-02-01', '1961-03-01', '1961-04-01', '1961-05-01', '1961-06-01', '1961-07-01', '1961-08-01', '1961-09-01', '1961-10-01', '1961-11-01', '1961-12-01', '1962-01-01', '1962-02-01', '1962-03-01', '1962-04-01', '1962-05-01', '1962-06-01', '1962-07-01', '1962-08-01', '1962-09-01', '1962-10-01', '1962-11-01', '1962-12-01', '1963-01-01', '1963-02-01', '1963-03-01', '1963-04-01', '1963-05-01', '1963-06-01', '1963-07-01', '1963-08-01', '1963-09-01', '1963-10-01', '1963-11-01', '1963-12-01', '1964-01-01', '1964-02-01', '1964-03-01', '1964-04-01', '1964-05-01', '1964-06-01', '1964-07-01', '1964-08-01', '1964-09-01', '1964-10-01', '1964-11-01', '1964-12-01', '1965-01-01', '1965-02-01', '1965-03-01', '1965-04-01', '1965-05-01', '1965-06-01', '1965-07-01', '1965-08-01', '1965-09-01', '1965-10-01', '1965-11-01', '1965-12-01', '1966-01-01', '1966-02-01', '1966-03-01', '1966-04-01', '1966-05-01', '1966-06-01', '1966-07-01', '1966-08-01', '1966-09-01', '1966-10-01', '1966-11-01', '1966-12-01', '1967-01-01', '1967-02-01', '1967-03-01', '1967-04-01', '1967-05-01', '1967-06-01', '1967-07-01', '1967-08-01', '1967-09-01', '1967-10-01', '1967-11-01', '1967-12-01', '1968-01-01', '1968-02-01', '1968-03-01', '1968-04-01', '1968-05-01', '1968-06-01', '1968-07-01', '1968-08-01', '1968-09-01', '1968-10-01', '1968-11-01']

# %%
# Convert that range into a dataframe that includes your predictions
# First, call DataFrame on pd

future_months = pd.DataFrame(date_range, columns = ['Month'])
# Let's now convert the 'Month' column to a datetime object with to_datetime

future_months['Month'] = pd.to_datetime(future_months['Month'])
future_months.set_index('Month', inplace = True)
future_months['Prediction'] = forecast
future_months.head()
# Out:
#             Prediction
# Month
# 1960-12-01         NaN
# 1961-01-01   13.815979
# 1961-02-01   13.816000
# 1961-03-01   13.816006
# 1961-04-01   13.816003

# %%
# Plot your future predictions
# Call figure() on plt
plt.figure(figsize=(15,10))
plt.plot(y_log)
plt.plot(y_log['Nov 1960'].append(future_months['Prediction']))
plt.show()

# %%
# Now plot the original variable y 
# Use the same functions as before
plt.figure(figsize=(20,10))
plt.plot(y)
plt.show()

# %%
plt.plot(np.exp(y_log['Nov 1960'].append(future_months['Prediction'])))
plt.show()

# %% [markdown]
# ## 4. Evaluating and Concluding
#
# Our model captures the centre of a line that's increasing at a remarkable rate. Cowboy Cigarettes sell more cigarettes in the summer, perhaps due to the good weather, disposable income and time off that people enjoy, and the least in the winter, when people might be spending less and enjoying less free time outdoors.
#
# Remarkably, our ARIMA model made predictions using just one variable. We can only speculate, however, on the causes of the behaviour predicted by our model. We should also take heed that spikes in data, due to sudden unusual circumstances like wars, are not handled well by ARIMA; and the outbreak of the Vietnam War in the 1960s would likely cause our model some distress.
#
# We could suggest to our employers that, if they are interested in discovering the causes of the cigarette sales trajectory, they execute a regression analysis in addition to the time series one.
